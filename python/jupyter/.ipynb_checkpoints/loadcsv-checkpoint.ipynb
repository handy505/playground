# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('pv1.csv')
df2 = pd.read_csv('pv2.csv')
df3 = pd.read_csv('pv3.csv')
df4 = pd.read_csv('pv4.csv')
df5 = pd.read_csv('pv5.csv')
df6 = pd.read_csv('pv6.csv')
df7 = pd.read_csv('pv7.csv')
df8 = pd.read_csv('pv8.csv')


plt.plot(df1.iloc[:,2])
plt.plot(df2.iloc[:,2])
plt.plot(df3.iloc[:,2])
plt.plot(df4.iloc[:,2])
plt.plot(df5.iloc[:,2])
plt.plot(df6.iloc[:,2])
plt.plot(df7.iloc[:,2])
plt.plot(df8.iloc[:,2])
plt.show()
