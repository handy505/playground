# %%
# 載入檔案
import pandas as pd
df = pd.read_csv('raw/B827EB6484B5_ID01_20181214_135816.txt')

# %%
# 偷看一下
#df.head()
#df.tail()

# %%
# 大概長什麼樣子
df.shape
# Out:
# (128, 6)

# %%
# 取出原始數據
volt1 = df.iloc[:,0]
current1 = df.iloc[:,1]
power1 = df.iloc[:,2]
volt2 = df.iloc[:,3]
current2 = df.iloc[:,4]
power2 = df.iloc[:,5]

# %%
# 畫個圖看看
from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(volt1, current1, color='blue')
plt.plot(volt2, current2, color='green')
plt.title('IV Curve')
# Out:
# Text(0.5, 1.0, 'IV Curve')

# %%
# 要動手認真取值了，取出IV曲線三個點的位置
def maxpower_vi(df):
    Voc = 0
    Ioc = 0
    Vsc = 0
    Isc = 0
    Vmp = 0
    Imp = 0
    Pmax = 0
    for index, row in df.iterrows():
        v = row[0]
        i = row[1]
        p = v*i
        if p > Pmax:
            Vmp = v
            Imp = i
            Pmax = p
            
        if v > Voc:
            Voc = v
            Ioc = i
            
        if i > Isc:
            Vsc = v
            Isc = i
            
    return Voc, Ioc, Vsc, Isc, Vmp, Imp

Voc, Ioc, Vsc, Isc, Vmp, Imp = maxpower_vi(df)
print(r'Short Circuit:({},{}), Max Power:({},{}) Open Circuit:({},{})'.format(Vsc, Isc, Vmp, Imp, Voc, Ioc))
# Out:
# Short Circuit:(2,97), Max Power:(731,88) Open Circuit:(864,0)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(volt1, current1, color='blue')
#plt.plot(volt2, current2, color='green')
plt.scatter(Vmp, Imp, color='red')
plt.scatter(Voc,Ioc, color='red')
plt.scatter(Vsc,Isc, color='red')
plt.annotate(r'Vmp,Imp', xy=(Vmp,Imp), xycoords='data', fontsize=18)
plt.annotate(r'Vsc,Isc', xy=(Vsc,Isc), xycoords='data', fontsize=18)
plt.annotate(r'Voc,Ioc', xy=(Voc,Ioc), xycoords='data', fontsize=18)
plt.title('IV Curve')
# Out:
# Text(0.5, 1.0, 'IV Curve')

# %%
# 兩點做一直線，得到兩個斜率，剩下的就用if做掉就可以了。
mh = (Imp-Isc)/(Vmp-Vsc)
mv = (Ioc-Imp)/(Voc-Vmp)
print('Slope of horizontal: {}'.format(mh))
print('Slope of vertical:   {}'.format(mv))
# Out:
# Slope of horizontal: -0.012345679012345678
# Slope of vertical:   -0.6616541353383458

# %%
# 如果想看原始資料，在這裡。
df
# Out:
#      0xC200  0xC280  0xC300  0xC380  0xC400  0xC480
# 0       864       0       0     865       0       0
# 1       863       0       0     865       0       0
# 2       863       0       0     865       0       0
# 3       863       0       0     865       0       0
# 4       863       0       0     866       0       0
# 5       863       0       0     866       0       0
# 6       863       0       0     866       0       0
# 7       863       0       0     866       0       0
# 8       863       0       0     865       0       0
# 9       863       0       0     865       0       0
# 10      863       0       0     865       0       0
# 11      863       0       0     865       0       0
# 12      863       0       0     865       0       0
# 13      863       0       0     865       0       0
# 14      863       0       0     865       0       0
# 15      863       0       0     865       0      29
# 16      859       3     318     860       5     511
# 17      855       9     814     856      12    1074
# 18      850      15    1344     851      18    1612
# 19      845      22    1884     845      26    2209
# 20      839      28    2427     839      33    2786
# 21      833      35    2970     833      40    3345
# 22      826      42    3483     826      47    3937
# 23      819      48    3994     819      54    4462
# 24      811      54    4448     812      60    4909
# 25      803      60    4847     804      66    5348
# 26      795      65    5217     796      72    5740
# 27      787      70    5527     787      77    6076
# 28      779      74    5808     779      81    6345
# 29      770      78    6020     770      85    6583
# ..      ...     ...     ...     ...     ...     ...
# 98      231      95    2204     231     104    2401
# 99      223      95    2123     223     104    2326
# 100     215      95    2053     215     104    2256
# 101     208      95    1980     208     104    2176
# 102     200      95    1909     200     104    2098
# 103     192      95    1836     193     104    2019
# 104     185      95    1765     185     104    1930
# 105     177      95    1698     177     103    1838
# 106     169      96    1628     169     103    1757
# 107     162      96    1560     161     103    1676
# 108     154      96    1490     154     103    1597
# 109     146      96    1417     146     103    1518
# 110     139      96    1346     139     103    1440
# 111     131      96    1272     131     103    1358
# 112     123      96    1194     123     103    1284
# 113     116      96    1120     115     103    1203
# 114     108      96    1042     108     104    1126
# 115     100      96     964     100     104    1050
# 116      92      96     892      92     104     969
# 117      85      96     822      85     104     893
# 118      77      96     747      77     104     814
# 119      70      96     674      70     104     733
# 120      62      96     601      62     104     653
# 121      54      96     527      54     104     570
# 122      47      96     454      47     104     491
# 123      39      96     380      39     104     408
# 124      31      96     306      31     104     328
# 125       2      97      22       2     104      26
# 126       0       0       0       0       0       0
# 127       0       0       0       0       0       0
#
# [128 rows x 6 columns]
