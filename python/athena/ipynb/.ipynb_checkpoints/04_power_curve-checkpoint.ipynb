# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
# %matplotlib inline
register_matplotlib_converters()

# %%
filename = 'data\AnXin-2020-0526.db'
with sqlite3.connect(filename) as con:
    df = pd.read_sql('''select * from inverter_minutely''', con=con)
    
df.LoggedDatetime = pd.to_datetime(df.LoggedDatetime) # datetime的部份，需先做過一次轉換
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/playground/python/athena/env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1696         try:
# -> 1697             cur.execute(*args, **kwargs)
#    1698             return cur
#
# OperationalError: no such table: inverter_minutely
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-5046cc3d6420> in <module>
#       1 filename = 'data\AnXin-2020-0526.db'
#       2 with sqlite3.connect(filename) as con:
# ----> 3     df = pd.read_sql('''select * from inverter_minutely''', con=con)
#       4
#       5 df.LoggedDatetime = pd.to_datetime(df.LoggedDatetime) # datetime的部份，需先做過一次轉換
#
# ~/playground/python/athena/env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     482
#     483     if isinstance(pandas_sql, SQLiteDatabase):
# --> 484         return pandas_sql.read_query(
#     485             sql,
#     486             index_col=index_col,
#
# ~/playground/python/athena/env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1741
#    1742         args = _convert_params(sql, params)
# -> 1743         cursor = self.execute(*args)
#    1744         columns = [col_desc[0] for col_desc in cursor.description]
#    1745
#
# ~/playground/python/athena/env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1707
#    1708             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1709             raise ex from exc
#    1710
#    1711     @staticmethod
#
# DatabaseError: Execution failed on sql 'select * from inverter_minutely': no such table: inverter_minutely

# %%
df.query('DeviceID == 1')
# Out:
#       UniqueID  DeviceID      LoggedDatetime    AlarmCode ErrorCode  \
# 0            1         1 2020-05-26 05:11:50  85899346080         0
# 7            8         1 2020-05-26 05:12:51  85899346080         0
# 14          15         1 2020-05-26 05:13:52  85899346080         0
# 21          22         1 2020-05-26 05:14:53  85899346080         0
# 28          29         1 2020-05-26 05:15:55  85899346080         0
# ...        ...       ...                 ...          ...       ...
# 5383      5384         1 2020-05-26 18:53:56            0         0
# 5390      5391         1 2020-05-26 18:54:59            0         0
# 5397      5398         1 2020-05-26 18:56:01            0         0
# 5404      5405         1 2020-05-26 18:57:03            0         0
# 5411      5412         1 2020-05-26 18:58:18            0         0
#
#       DC1Voltage  DC2Voltage  DC3Voltage  DC4Voltage  DC1Current  ...  \
# 0          662.0       663.0       662.0       662.0         0.0  ...
# 7          669.0       669.0       669.0       669.0         0.0  ...
# 14         675.0       675.0       675.0       675.0         0.0  ...
# 21         682.0       682.0       682.0       682.0         0.0  ...
# 28         689.0       690.0       689.0       689.0         0.0  ...
# ...          ...         ...         ...         ...         ...  ...
# 5383       204.0       201.0       213.0       210.0         0.0  ...
# 5390       208.0       206.0       196.0       220.0         0.0  ...
# 5397       205.0       205.0       199.0       210.0         0.0  ...
# 5404       200.0       201.0       204.0       205.0         0.0  ...
# 5411       179.0       177.0       176.0       178.0         0.0  ...
#
#       HeatSinkTemp  AC1Voltage  AC2Voltage  AC3Voltage  AC1Current  \
# 0               32       282.0       283.0       281.0         0.1
# 7               32       283.0       283.0       281.0         0.1
# 14              32       282.0       283.0       281.0         0.1
# 21              32       282.0       282.0       280.0         0.1
# 28              32       283.0       283.0       280.0         0.1
# ...            ...         ...         ...         ...         ...
# 5383            35       280.0       280.0       279.0         2.0
# 5390            35       280.0       277.0       278.0         1.9
# 5397            35       282.0       281.0       279.0         1.9
# 5404            35       281.0       281.0       279.0         1.9
# 5411            35       280.0       279.0       277.0         1.9
#
#       AC2Current  AC3Current  ACFrequency  ACOutputPower      KWH
# 0            0.0         0.0         60.1            0.0  73508.0
# 7            0.0         0.0         60.1            0.0  73508.0
# 14           0.0         0.0         60.1            0.0  73508.0
# 21           0.0         0.0         59.9            0.0  73508.0
# 28           0.0         0.0         60.0            0.0  73508.0
# ...          ...         ...          ...            ...      ...
# 5383         2.0         1.9         60.0            0.0  73653.0
# 5390         1.9         1.9         60.0            0.0  73653.0
# 5397         1.9         1.9         60.0            0.0  73653.0
# 5404         1.9         1.9         59.9            0.0  73653.0
# 5411         1.9         1.8         60.0            0.0  73653.0
#
# [774 rows x 30 columns]

# %%
dfs = {}
device_identifies = [1,2,3,4,5,18,19]
for id in device_identifies:
    cmd = 'DeviceID == {}'.format(id)
    dfs[id] = df.query(cmd)

# %%
#fig, ax = plt.subplots(2, 1, sharex='col', sharey='row')
fig, ax = plt.subplots(1)

for id in device_identifies:
    print(id)
    df = dfs.get(id)
    ax.plot(df.LoggedDatetime, df.ACOutputPower)
ax.set_title(filename)
# Out:
# 1
# 2
# 3
# 4
# 5
# 18
# 19
# Text(0.5, 1.0, 'solardb\\AnXin-2020-0526.db')

# %%
fig, axes = plt.subplots(2, 3, sharex='col', sharey='row')
fig.set_figheight(15)
fig.set_figwidth(15)

df1 = dfs.get(1)
axes[0,0].plot(df.LoggedDatetime, df.ACOutputPower)

df2 = dfs.get(2)
axes[0,1].plot(df.LoggedDatetime, df.ACOutputPower)

df = dfs.get(18)
axes[0,2].plot(df.LoggedDatetime, df.ACOutputPower)

df = dfs.get(19)
axes[1,0].plot(df.LoggedDatetime, df.ACOutputPower)
